# %% [markdown]
# # CLASE 7

# %%
#pip install pandas

# %%
#pip install numpy

# %%
#pip install openpyxl

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('mic2.xlsx',
                  engine = 'openpyxl')
df.head()
# Out:
#    Age     Sex  Ocupation  Monthly income   Price  Quality  Quantity  \
# 0   31    Male  Research          >40, 000      5        5         5
# 1   25    Male    student          <10,000      3        5         3
# 2   45  Female   Teaching         >40, 000      3        4         4
# 3   27    Male    Student          <10,000      5        5         3
# 4   23  Female      Tutor  10,000 - 20,000      5        5         4
#
#    Availability  Taste  Flavours  ...  Overal satisfaction  Consistency  \
# 0             4      4         5  ...                    4            4
# 1             4      5         5  ...                    4            4
# 2             4      3         4  ...                    4            4
# 3             4      5         5  ...                    4            4
# 4             4      5         5  ...                    5            5
#
#     Factor  Frowned           reason    Popular My favorite  \
# ...

# %%
def custom_cls(x):
    if (0<= x <=20):
        return '0 a 20'
    elif(21<= x <= 30):
        return '21 a 30'
    elif(31<= x <= 40):
        return '31 a 40'
    else:
        return 'Mayor a 40'

# %%
df['Age Range'] = df.apply(lambda tbl: custom_cls(tbl['Age']), axis = 1)
df.head(2)
# Out:
#    Age   Sex  Ocupation Monthly income   Price  Quality  Quantity  \
# 0   31  Male  Research         >40, 000      5        5         5
# 1   25  Male    student         <10,000      3        5         3
#
#    Availability  Taste  Flavours  ...  Consistency  Factor  Frowned  \
# 0             4      4         5  ...            4   Taste       No
# 1             4      5         5  ...            4   Taste       No
#
#             reason    Popular  My favorite                     Kind  \
# 0              NaN  Combo_VLM    Chocolate  More than one flavoured
# 1  Quantity issues  Combo_VCS    Chocolate  More than one flavoured
#
#   Preference Recommend Age Range
# 0      agree     agree   31 a 40
# 1    neutral   neutral   21 a 30
#
# [2 rows x 25 columns]

# %%
counts = df['Age Range'].value_counts()
counts = counts.to_frame()
counts
# Out:
#             Age Range
# 21 a 30            31
# 0 a 20             11
# 31 a 40             5
# Mayor a 40          3

# %%
counts['%'] = counts.iloc[:, :]/counts.loc[:,'Age Range'].sum(axis=0)*100
counts
# Out:
#             Age Range     %
# 21 a 30            31  62.0
# 0 a 20             11  22.0
# 31 a 40             5  10.0
# Mayor a 40          3   6.0
